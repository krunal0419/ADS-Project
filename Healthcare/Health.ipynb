# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn import metrics
import joblib
from tkinter import *
# Importing the dataset
df = pd.read_csv('insurance.csv')
# Converting categorical columns to numerical
df['sex'] = df['sex'].map({'female': 0, 'male': 1})
df['smoker'] = df['smoker'].map({'yes': 1, 'no': 0})
df['region'] = df['region'].map({'southwest': 1, 'southeast': 2, 'northwest': 3, 'northeast': 4})

# Storing Features Matrix in X and response in Y
X = df.drop(['charges'], axis=1)
Y = df['charges']

# Splitting the dataset into the Training set and Test set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# Model Training
lr = LinearRegression()
lr.fit(X_train, Y_train)
sv = SVR()
sv.fit(X_train, Y_train)
rf = RandomForestRegressor()
rf.fit(X_train, Y_train)
gb = GradientBoostingRegressor()
gb.fit(X_train, Y_train)

# Prediction on Test Data
Y_pred1 = lr.predict(X_test)
Y_pred2 = sv.predict(X_test)
Y_pred3 = rf.predict(X_test)
Y_pred4 = gb.predict(X_test)

# Evaluating the Models
score1 = metrics.r2_score(Y_test, Y_pred1)
score2 = metrics.r2_score(Y_test, Y_pred2)
score3 = metrics.r2_score(Y_test, Y_pred3)
score4 = metrics.r2_score(Y_test, Y_pred4)

s1 = metrics.mean_absolute_error(Y_test, Y_pred1)
s2 = metrics.mean_absolute_error(Y_test, Y_pred2)
s3 = metrics.mean_absolute_error(Y_test, Y_pred3)
s4 = metrics.mean_absolute_error(Y_test, Y_pred4)

# Charges prediction for new customer
data = {'age': 40, 'sex': 1, 'bmi': 50.5, 'children': 3, 'smoker': 1, 'region': 2}
df_new = pd.DataFrame(data, index=[0])
new_pred = gb.predict(df_new)

# Saving the Model
joblib.dump(gb, 'model_joblib_gb')
# Out:
# ['model_joblib_gb']

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('insurance.csv')

df['sex'] = df['sex'].map({'female': 0, 'male': 1})
df['smoker'] = df['smoker'].map({'yes': 1, 'no': 0})
df['region'] = df['region'].map({'southwest': 1, 'southeast': 2, 'northwest': 3, 'northeast': 4})

# Calculate the correlation matrix
corr_matrix = df.corr()

# Plot the correlation matrix as a heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f", linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('insurance.csv')

# Calculate the correlation between 'age' and 'charges'
age_charge_corr = df['age'].corr(df['charges'])

print("Correlation between 'age' and 'charges':", age_charge_corr)

# If you want to visualize the relationship, you can plot a scatter plot
import matplotlib.pyplot as plt

plt.scatter(df['age'], df['charges'])
plt.xlabel('Age')
plt.ylabel('Charges')
plt.title('Age vs Charges')
plt.show()
# Out:
# Correlation between 'age' and 'charges': 0.2990081933306476

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('insurance.csv')

# Convert 'sex' to numerical values (0 for female, 1 for male)
df['sex'] = df['sex'].map({'female': 0, 'male': 1})

# Calculate the correlation between 'sex' and 'charges'
sex_charge_corr = df['sex'].corr(df['charges'])

print("Correlation between 'sex' and 'charges':", sex_charge_corr)

# If you want to visualize the relationship, you can plot a scatter plot
import matplotlib.pyplot as plt

plt.scatter(df['sex'], df['charges'], c=df['sex'], cmap='coolwarm', alpha=0.7)
plt.xlabel('Sex (0: Female, 1: Male)')
plt.ylabel('Charges')
plt.title('Sex vs Charges')
plt.xticks(ticks=[0, 1], labels=['Female', 'Male'])
plt.colorbar(label='Sex')
plt.show()
# Out:
# Correlation between 'sex' and 'charges': 0.05729206220202532

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('insurance.csv')

# Calculate the correlation between 'bmi' and 'charges'
bmi_charge_corr = df['bmi'].corr(df['charges'])

print("Correlation between 'bmi' and 'charges':", bmi_charge_corr)

# If you want to visualize the relationship, you can plot a scatter plot
import matplotlib.pyplot as plt

plt.scatter(df['bmi'], df['charges'])
plt.xlabel('BMI')
plt.ylabel('Charges')
plt.title('BMI vs Charges')
plt.show()
# Out:
# Correlation between 'bmi' and 'charges': 0.19834096883362878

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('insurance.csv')

# Calculate the correlation between 'children' and 'charges'
children_charge_corr = df['children'].corr(df['charges'])

print("Correlation between 'children' and 'charges':", children_charge_corr)

# If you want to visualize the relationship, you can plot a scatter plot
import matplotlib.pyplot as plt

plt.scatter(df['children'], df['charges'])
plt.xlabel('Number of Children')
plt.ylabel('Charges')
plt.title('Number of Children vs Charges')
plt.show()
# Out:
# Correlation between 'children' and 'charges': 0.06799822684790469

# %%
import pandas as pd

# Read the dataset
df = pd.read_csv('insurance.csv')

# Convert 'smoker' to numerical values (0 for no, 1 for yes)
df['smoker'] = df['smoker'].map({'no': 0, 'yes': 1})

# Calculate the correlation between 'smoker' and 'charges'
smoker_charge_corr = df['smoker'].corr(df['charges'])

print("Correlation between 'smoker' and 'charges':", smoker_charge_corr)

# If you want to visualize the relationship, you can plot a scatter plot
import matplotlib.pyplot as plt

plt.scatter(df['smoker'], df['charges'], c=df['smoker'], cmap='coolwarm', alpha=0.7)
plt.xlabel('Smoker (0: Non-Smoker, 1: Smoker)')
plt.ylabel('Charges')
plt.title('Smoker vs Charges')
plt.xticks(ticks=[0, 1], labels=['Non-Smoker', 'Smoker'])
plt.colorbar(label='Smoker')
plt.show()
# Out:
# Correlation between 'smoker' and 'charges': 0.7872514304984782
